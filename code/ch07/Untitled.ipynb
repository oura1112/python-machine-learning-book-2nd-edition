# %%
import pandas as pd
from sklearn import datasets
boston = datasets.load_boston()
df = df = pd.DataFrame(boston['data'], columns=boston['feature_names'])
df.corr().style.background_gradient(axis=None)
# Out:
# <style  type="text/css" >
#     #T_757039b0_ec03_11ea_82c7_04ea563d1499row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_757039b0_ec03_11ea_82c7_04ea563d1499row0_col1 {
#             background-color:  #b8c6e0;
#             color:  #000000;
#         }    #T_757039b0_ec03_11ea_82c7_04ea563d1499row0_col2 {
#             background-color:  #2685bb;
#             color:  #000000;
#         }    #T_757039b0_ec03_11ea_82c7_04ea563d1499row0_col3 {
#             background-color:  #9ab8d8;
#             color:  #000000;
#         }    #T_757039b0_ec03_11ea_82c7_04ea563d1499row0_col4 {
#             background-color:  #2383ba;
#             color:  #000000;
#         }    #T_757039b0_ec03_11ea_82c7_04ea563d1499row0_col5 {
#             background-color:  #bcc7e1;
#             color:  #000000;
#         }    #T_757039b0_ec03_11ea_82c7_04ea563d1499row0_col6 {
#             background-color:  #328dbf;
#             color:  #000000;
# ...
